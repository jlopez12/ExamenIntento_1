# %% [markdown]
# <a href="https://colab.research.google.com/github/jlopez12/ExamenIntento_1/blob/main/ExamenIntento_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Conectar a Drive y leer documento

# %%
# Conectar Colab con drive.
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Importa librerias a utilizar.
import pandas as pd
import plotly.express as px

# %%
# Establecer conexion al documento
path = "/content/drive/MyDrive/Colab Notebooks/DB/WA_Fn-UseC_-Telco-Customer-Churn.csv"
df = pd.read_csv(path)

# %% [markdown]
# #Primera vista al Data Frame

# %%
# Se revisan las columnas y tipos de datos.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %% [markdown]
# #Limpieza de columnas

# %%
# Pasa todas las columnas a minusculas y se aplica un borrado de espacios para asegurar que no exitan.
df.columns = df.columns.str.lower().str.strip()

# %%
# Vemos los primeros 20 registros.
df.head(20)
# Out:
#     customerid  gender  seniorcitizen partner dependents  tenure phoneservice  \
# 0   7590-VHVEG  Female              0     Yes         No       1           No
# 1   5575-GNVDE    Male              0      No         No      34          Yes
# 2   3668-QPYBK    Male              0      No         No       2          Yes
# 3   7795-CFOCW    Male              0      No         No      45           No
# 4   9237-HQITU  Female              0      No         No       2          Yes
# 5   9305-CDSKC  Female              0      No         No       8          Yes
# 6   1452-KIOVK    Male              0      No        Yes      22          Yes
# 7   6713-OKOMC  Female              0      No         No      10           No
# 8   7892-POOKP  Female              0     Yes         No      28          Yes
# 9   6388-TABGU    Male              0      No        Yes      62          Yes
# 10  9763-GRSKD    Male              0     Yes        Yes      13          Yes
# ...

# %% [markdown]
# #Revisión de datos

# %%
# Muestra las filas con algun valor null
df[df.isnull().any(axis=1)]
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
# Identificar valores nulos en todo el DataFrame
print(df.isnull().sum())
# Out:
# customerid          0
# gender              0
# seniorcitizen       0
# partner             0
# dependents          0
# tenure              0
# phoneservice        0
# multiplelines       0
# internetservice     0
# onlinesecurity      0
# onlinebackup        0
# deviceprotection    0
# techsupport         0
# streamingtv         0
# streamingmovies     0
# contract            0
# paperlessbilling    0
# paymentmethod       0
# monthlycharges      0
# totalcharges        0
# churn               0
# dtype: int64

# %%
# Validacion de datos duplicados.
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No se identifican datos duplicados ni filas con algun valor en Null

# %% [markdown]
# * Verificacion de tipo de datos en cada columa.

# %%
# Volvemos a consultar las columas y tipos de datos asignado.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
# ...

# %%
# Segun los nombres de las columas se identifican algunas que deberian ser de tipo numerico
"""
Columnas que deberian ser de tipo numerico
seniorcitizen, tenure, monthlycharges, 	totalcharges
Para este caso solo la columna totalcharges se identifica como object por lo que se decide aplicar
conversion del dato a tipo float
"""
df["totalcharges"] = df["totalcharges"].astype(float)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-40-1690661237> in <cell line: 0>()
#       6 conversion del dato a tipo float
#       7 """
# ----> 8 df["totalcharges"] = df["totalcharges"].astype(float)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
# ...

# %% [markdown]
# * Al intentar hacer la conversion de datos a la columna totalcharges, arroja un error el que nos indica que no se puede convertir un espacio a tipo float, debido a este error se decide aplicar un strip para quitar espacios a los valores.

# %%
df["totalcharges"] = df["totalcharges"].str.strip()

# %%
# Quitados los espacios se hace una verificacion de datos en la columna
df["totalcharges"].value_counts()
# Out:
# totalcharges
#            11
# 20.2       11
# 19.75       9
# 20.05       8
# 19.9        8
#            ..
# 130.15      1
# 3211.9      1
# 7843.55     1
# 2196.3      1
# 197.4       1
# Name: count, Length: 6531, dtype: int64

# %% [markdown]
# Se identifican 11 registros que no tienen informacion en totalcharges

# %%
# Para los datos que no tiene informacion se aplicara que reemplace los vacios asignando un null
df["totalcharges"].replace("",pd.NA, inplace = True) # se agrea inplace true para que se aplique el cambio al df

# %%
# Muestra las filas con algun valor null
df[df.isnull().any(axis=1)]
# Out:
#       customerid  gender  seniorcitizen partner dependents  tenure  \
# 488   4472-LVYGI  Female              0     Yes        Yes       0
# 753   3115-CZMZD    Male              0      No        Yes       0
# 936   5709-LVOEQ  Female              0     Yes        Yes       0
# 1082  4367-NUYAO    Male              0     Yes        Yes       0
# 1340  1371-DWPAZ  Female              0     Yes        Yes       0
# 3331  7644-OMVMY    Male              0     Yes        Yes       0
# 3826  3213-VVOLG    Male              0     Yes        Yes       0
# 4380  2520-SGTTA  Female              0     Yes        Yes       0
# 5218  2923-ARZLG    Male              0     Yes        Yes       0
# 6670  4075-WKNIU  Female              0     Yes        Yes       0
# 6754  2775-SEFEE    Male              0      No        Yes       0
#
#      phoneservice     multiplelines internetservice       onlinesecurity  ...  \
# 488            No  No phone service             DSL                  Yes  ...
# ...

# %%
# Revisando la informacion se detecta que los clientes que no tienen totalcharges tienen un tenure en 0
fltr = (df["tenure"] == 0)
df[fltr]["totalcharges"]
# Out:
# 488     <NA>
# 753     <NA>
# 936     <NA>
# 1082    <NA>
# 1340    <NA>
# 3331    <NA>
# 3826    <NA>
# 4380    <NA>
# 5218    <NA>
# 6670    <NA>
# 6754    <NA>
# Name: totalcharges, dtype: object

# %% [markdown]
# Al no tener un valor en tenure osea numeros de meses que lleva con la empresa, es correcto que no tengan un total asignado aun.
#
# Debido a esto se decide cambiar ahora los NA a un valor 0 para poder usar la columna totalcharges como tipo numerico.

# %%
# Se aplica el metodo fillna de pd para poder cambiar un valor null
df["totalcharges"].fillna(0, inplace = True)

# %%
# Se revisan los totalcharge para los clientes que no tienen aun meses de servicio
fltr = (df["tenure"] == 0)
df[fltr]["totalcharges"]
# Out:
# 488     0
# 753     0
# 936     0
# 1082    0
# 1340    0
# 3331    0
# 3826    0
# 4380    0
# 5218    0
# 6670    0
# 6754    0
# Name: totalcharges, dtype: object

# %% [markdown]
# Se confirma que el cambio se ha realizado con exito por lo que se procede a cambiar el tipo de dato para la columna.

# %%
df["totalcharges"] = df["totalcharges"].astype(float)

# %%
# Confirmamos el cambio aplicado.
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   seniorcitizen     7043 non-null   int64
#  3   partner           7043 non-null   object
#  4   dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   phoneservice      7043 non-null   object
#  7   multiplelines     7043 non-null   object
#  8   internetservice   7043 non-null   object
#  9   onlinesecurity    7043 non-null   object
#  10  onlinebackup      7043 non-null   object
#  11  deviceprotection  7043 non-null   object
#  12  techsupport       7043 non-null   object
#  13  streamingtv       7043 non-null   object
#  14  streamingmovies   7043 non-null   object
#  15  contract          7043 non-null   object
# ...

# %%
# Verificacion de valores en gender (solo debe ser Male o Female)
df["gender"].value_counts()
# Out:
# gender
# Male      3555
# Female    3488
# Name: count, dtype: int64

# %%
# Verificacion de valores en seniorcitizen (solo pueden ser 0 o 1)
df["seniorcitizen"].value_counts()
# Out:
# seniorcitizen
# 0    5901
# 1    1142
# Name: count, dtype: int64

# %% [markdown]
# para este caso al ser valores 0 y 1 se considerea que queda mejor convertir el dato a tipo boolean.

# %%
df["seniorcitizen"] = df["seniorcitizen"].astype(bool)

# %%
# Se confirma el cambio
df["seniorcitizen"].value_counts()
# Out:
# seniorcitizen
# False    5901
# True     1142
# Name: count, dtype: int64

# %%
# Verificacion de valores en partner (solo pueden ser Yes o No)
df["partner"].value_counts()
# Out:
# partner
# No     3641
# Yes    3402
# Name: count, dtype: int64

# %%
# Debido a la cantidad de columnas se decide aplicar un metodo apply para aplicar a columnas especificas el value_counts
df[["dependents","phoneservice","multiplelines",
    "internetservice","onlinesecurity","onlinebackup",
    "deviceprotection","techsupport","streamingtv","streamingmovies",
    "contract","paperlessbilling","paymentmethod","churn"]].apply(lambda col: col.value_counts())
# Out:
#                            dependents  phoneservice  multiplelines  \
# Bank transfer (automatic)         NaN           NaN            NaN
# Credit card (automatic)           NaN           NaN            NaN
# DSL                               NaN           NaN            NaN
# Electronic check                  NaN           NaN            NaN
# Fiber optic                       NaN           NaN            NaN
# Mailed check                      NaN           NaN            NaN
# Month-to-month                    NaN           NaN            NaN
# No                             4933.0         682.0         3390.0
# No internet service               NaN           NaN            NaN
# No phone service                  NaN           NaN          682.0
# One year                          NaN           NaN            NaN
# Two year                          NaN           NaN            NaN
# Yes                            2110.0        6361.0         2971.0
#
# ...

# %% [markdown]
# Segun la informacion revisada no se han detectado inconcistencias en los valores. y ya no se tienen registros vacios o tipos de datos mal asignados, por lo que se da por completada la verificacion y limpieza de datos

# %% [markdown]
# #Exploracion de datos.

# %% [markdown]
# Crear dos tipos diferentes de visualizaciones exploratorias univariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.

# %%
# Creamos el grafico de caja para ver la cantidad de usuarios por genero
fig = px.pie(df,
             names="gender",
             title="Porcentaje de Clientes por Género",
             labels={"gender": "Género"},# remobra etiquetas
             )
fig.update_layout(title_font_size=18)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Como se observa el porcentaje de Clientes por genero es similar, aunque se ve que por muy poco la mayoria son hombres.

# %%
# Se crea un histograma para visualizar el metodo de pago.
fig = px.histogram(df,
             x="paymentmethod",
             title="Distribución por Metodos de Pago.",
             labels={"paymentmethod":"Metodo de Pago"},# remobra etiquetas
             color_discrete_sequence=['skyblue']
             )
fig.update_layout(title_font_size=18)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Segun la grafica enterior se identifica que el metodo de pago mas utilizado es "Electronick check", mientras que las demas se mantiene en una cantidad de uso similar.

# %% [markdown]
# * Crear dos tipos diferentes de visualizaciones exploratorias multivariadas. Cada visualización debe incluir una breve interpretación dentro del archivo de código.

# %%
# Creamos el grafico de caja para ver la distribucion de meses segun el genero.
fig = px.box(df,
             x="gender",
             y="tenure",
             title="Promedio de Meses en Servicio, Segun el Género.",
             labels={"tenure":"Tenure (Meses)","gender": "Género"},# remobra etiquetas
             color="gender" # se indica que valor diferenciara por color
             )
fig.update_layout(title_font_size=18)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# * Segun la informacion visualizada se detecta que para ambos generos la distribucion de meses en servicio es similar, teniendo entre ellos la misma mediana.

# %%
# Se hace un grafico de dispersion / burbuja para revisar la distribucion de total de cargos y tenure segu medio de pago
fig = px.scatter(
    df,
    x="tenure",
    y="totalcharges",
    color="paymentmethod", # que dato se usara para diferenciar por colores
    size="monthlycharges", # que determina el tamaño del simbolo
    symbol="paymentmethod", # que dato se usara para diferenciar por simbolo
    title="Distribución de Total de Cargos y Tenure según Metodos de Pago ",
    hover_data=["paymentmethod"], # informacion que se mostrara al pasar el cursor
    labels={"paymentmethod":"Metodo de Pago",
            "tenure":"Tenure (Meses)",
            "totalcharges":"Cargo Total Cobrado"
            },# remobra etiquetas
)
fig.update_layout(title_font_size=18)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# Segun el grafico se identifica que no hay un metodo de pago preferido para los clientes ya que todos tienen una gran cantidad de uso y tampoco depende del cargo mensual, el metodo de pago que se elige. Apesar de que en el histograma antes realizado se veia que Electronic check tenia una mayor preferencia, aca se confirma que esa preferencia se diferencia por poco de las demas.
